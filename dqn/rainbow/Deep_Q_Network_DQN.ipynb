# %% [markdown]
# # Deep Q-Network (DQN)
# ---
# In this notebook, you will implement a DQN agent with OpenAI Gym's LunarLander-v2 environment.
#
# ### 1. Import the Necessary Packages

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os 
import sys

repo_path = os.path.dirname(os.path.dirname(os.path.dirname(os.path.abspath("__file__"))))
sys.path.append(repo_path)

# %%
repo_path
# Out:
# 'C:\\Users\\manua\\Documents\\repos\\udacity\\deep-reinforcement-learning'

# %%
from src.dqn_agent import AgentDQ, AgentDoubleDQ, AgentDuelDQ
from src.dqn import train

# %%
import gym
#!pip3 install box2d
import random
import torch
import numpy as np
from collections import deque
import matplotlib.pyplot as plt
# %matplotlib inline

#!python -m pip install pyvirtualdisplay
#from pyvirtualdisplay import Display
#display = Display(visible=0, size=(1400, 900))
#display.start()

is_ipython = 'inline' in plt.get_backend()
if is_ipython:
    from IPython import display

plt.ion()

# %% [markdown]
# ### 2. Instantiate the Environment and Agent
#
# Initialize the environment in the code cell below.

# %%
env = gym.make('LunarLander-v2')
env.seed(0)
print('State shape: ', env.observation_space.shape)
print('Number of actions: ', env.action_space.n)
# Out:
# State shape:  (8,)
# Number of actions:  4

# %% [markdown]
# Before running the next code cell, familiarize yourself with the code in **Step 2** and **Step 3** of this notebook, along with the code in `dqn_agent.py` and `model.py`.  Once you have an understanding of how the different files work together,
# - Define a neural network architecture in `model.py` that maps states to action values.  This file is mostly empty - it's up to you to define your own deep Q-network!
# - Finish the `learn` method in the `Agent` class in `dqn_agent.py`.  The sampled batch of experience tuples is already provided for you; you need only use the local and target Q-networks to compute the loss, before taking a step towards minimizing the loss.
#
# Once you have completed the code in `dqn_agent.py` and `model.py`, run the code cell below.  (_If you end up needing to make multiple changes and get unexpected behavior, please restart the kernel and run the cells from the beginning of the notebook!_)
#
# You can find the solution files, along with saved model weights for a trained agent, in the `solution/` folder.  (_Note that there are many ways to solve this exercise, and the "solution" is just one way of approaching the problem, to yield a trained agent._)

# %%
agent_dq = AgentDQ(state_size=8, action_size=4, gamma=0.99, hidden_layers=[64, 32], drop_p=None,
                 batch_size=64, learning_rate=5e-4, soft_upd_param=1e-3, update_every=4, buffer_size=int(1e5), seed=123)

# %%
hist = []
# watch an untrained agent
state = env.reset()
img = plt.imshow(env.render(mode='rgb_array'))
for j in range(200):
    
    action = agent_dq.act(state)
    exp = (state, action)
    img.set_data(env.render(mode='rgb_array')) 
    plt.axis('off')
    display.display(plt.gcf())
    display.clear_output(wait=True)
    state, reward, done, _ = env.step(action)
    exp = exp + (reward,)
    hist.append(exp)
    if done:
        break 
        
env.close()

# %% [markdown]
# ### 3. Train the Agent with DQN
#
# Run the code cell below to train the agent from scratch.  You are welcome to amend the supplied values of the parameters in the function, to try to see if you can get better performance!

# %%
# add a new agent to benchmark them
agent_doubledq = AgentDoubleDQ(state_size=8, action_size=4, gamma=0.99, hidden_layers=[64, 32], drop_p=None,
                 batch_size=64, learning_rate=5e-4, soft_upd_param=1e-3, update_every=4, buffer_size=int(1e5), seed=123)

agent_dueldq = AgentDuelDQ(state_size=8, action_size=4, gamma=0.99, hidden_layers=[64,32], drop_p=None,
                 batch_size=64, learning_rate=5e-4, soft_upd_param=1e-3, update_every=4, buffer_size=int(1e5), seed=123)

# %%
scores_dq = train(env, agent_dq, n_episodes=2000, max_t=1000, 
        eps_start=1.0, eps_end=0.01, eps_decay=0.995, model_save_path='models/dq_checkpoint_v01.pth')
# Out:
# Episode 100	Average Score: -138.97
# Episode 200	Average Score: -102.64
# Episode 300	Average Score: -79.270
# Episode 400	Average Score: -46.36
# Episode 500	Average Score: -28.32
# Episode 600	Average Score: 112.36
# Episode 684	Average Score: 200.02
# Environment solved in 584 episodes!	Average Score: 200.02

# %%
scores_doubledq = train(env, agent_doubledq, n_episodes=2000, max_t=1000, 
        eps_start=1.0, eps_end=0.01, eps_decay=0.995, model_save_path='models/doubledq_checkpoint_v01.pth')
# Out:
# Episode 100	Average Score: -159.74
# Episode 200	Average Score: -75.413
# Episode 300	Average Score: -118.80
# Episode 400	Average Score: -17.482
# Episode 500	Average Score: 11.057
# Episode 600	Average Score: 85.24
# Episode 700	Average Score: 198.92
# Episode 701	Average Score: 200.64
# Environment solved in 601 episodes!	Average Score: 200.64

# %%
scores_dueldq = train(env, agent_dueldq, n_episodes=2000, max_t=1000, 
        eps_start=1.0, eps_end=0.01, eps_decay=0.995, model_save_path='models/dueldq_checkpoint_v01.pth')
# Out:
# Episode 100	Average Score: -170.67
# Episode 200	Average Score: -179.97
# Episode 300	Average Score: -172.22
# Episode 400	Average Score: -202.25
# Episode 500	Average Score: -185.56
# Episode 600	Average Score: -220.36
# Episode 700	Average Score: -189.70
# Episode 800	Average Score: -190.09
# Episode 900	Average Score: -48.088
# Episode 1000	Average Score: -47.61
# Episode 1100	Average Score: -57.32
# Episode 1200	Average Score: -39.98
# Episode 1300	Average Score: -29.65
# Episode 1400	Average Score: -28.65
# Episode 1500	Average Score: -9.293
# Episode 1600	Average Score: -7.129
# Episode 1700	Average Score: 21.82
# Episode 1800	Average Score: 159.13
# Episode 1832	Average Score: 200.18
# Environment solved in 1732 episodes!	Average Score: 200.18

# %%
import datetime as dt
import pandas as pd
experiment_dt = dt.datetime.strftime(dt.datetime.now(), "%Y%m%d%H%M%S")

# %%
checkpoint_metadata_dq = pd.Series(index=['N_episodes', 'gamma', 'hidden_layers', 'drop_p',
                 'batch_size', 'learning_rate', 'soft_upd_param', 'update_every', 'buffer_size',
                'checkpoint'],
         data = [len(scores_dq), 0.99, [64, 32], None, 64, 5e-4, 1e-3, 4, int(1e5), 'dq_checkpoint_v01.pth'], name='experiment:dqn:v01')
checkpoint_metadata_dq
# Out:
# N_episodes                          684
# gamma                              0.99
# hidden_layers                  [64, 32]
# drop_p                             None
# batch_size                           64
# learning_rate                    0.0005
# soft_upd_param                    0.001
# update_every                          4
# buffer_size                      100000
# checkpoint        dq_checkpoint_v01.pth
# Name: experiment:dqn:v01, dtype: object

# %%
checkpoint_metadata_doubledq = pd.Series(index=['N_episodes', 'gamma', 'hidden_layers', 'drop_p',
                 'batch_size', 'learning_rate', 'soft_upd_param', 'update_every', 'buffer_size',
                'checkpoint'],
         data = [len(scores_dq), 0.99, [64, 32], None, 64, 5e-4, 1e-3, 4, int(1e5), 'doubledq_checkpoint_v01.pth'], name='experiment:doubledqn:v01')
checkpoint_metadata_dq
# Out:
# N_episodes                          684
# gamma                              0.99
# hidden_layers                  [64, 32]
# drop_p                             None
# batch_size                           64
# learning_rate                    0.0005
# soft_upd_param                    0.001
# update_every                          4
# buffer_size                      100000
# checkpoint        dq_checkpoint_v01.pth
# Name: experiment:dqn:v01, dtype: object

# %%
checkpoint_metadata_dueldq = pd.Series(index=['N_episodes', 'gamma', 'hidden_layers', 'drop_p',
                 'batch_size', 'learning_rate', 'soft_upd_param', 'update_every', 'buffer_size',
                'checkpoint'],
         data = [len(scores_dq), 0.99, [64, 32], None, 64, 5e-4, 1e-3, 4, int(1e5), 'dq_checkpoint_v01.pth'], name='experiment:dueldq:v01')
checkpoint_metadata_dueldq
# Out:
# N_episodes                          684
# gamma                              0.99
# hidden_layers                  [64, 32]
# drop_p                             None
# batch_size                           64
# learning_rate                    0.0005
# soft_upd_param                    0.001
# update_every                          4
# buffer_size                      100000
# checkpoint        dq_checkpoint_v01.pth
# Name: experiment:dueldq:v01, dtype: object

# %%
checkpoint_metadata_df = pd.concat([
    checkpoint_metadata_dq.to_frame().T,
    checkpoint_metadata_doubledq.to_frame().T,
    checkpoint_metadata_dueldq.to_frame().T,
], axis=0)

checkpoint_metadata_df.to_json(f'models/experiments/hparams_{experiment_dt}')

# %%
scores_dq_df = scores_dq.to_frame('score')
scores_dq_df['score_mave100'] = scores_dq_df['score'].rolling(100).mean()
scores_dq_df['experiment'] = 'dqn:v01'

scores_doubledq_df = scores_doubledq.to_frame('score')
scores_doubledq_df['score_mave100'] = scores_doubledq_df['score'].rolling(100).mean()
scores_doubledq_df['experiment'] = 'doubledq:v01'

scores_dueldq_df = scores_dueldq.to_frame('score')
scores_dueldq_df['score_mave100'] = scores_dueldq_df['score'].rolling(100).mean()
scores_dueldq_df['experiment'] = 'dueldq:v01'

scores_df = pd.concat([scores_dq_df, scores_doubledq_df, scores_dueldq_df], axis=0)
scores_df.to_csv(f'models/experiments/scores_{experiment_dt}')

# %%
experiments= ['dqn:v01', 'doubledq:v01', 'dueldq:v01']

# %%
fig, axs = plt.subplots(len(experiments),1, figsize=(16,24))

for row_idx, ax in enumerate(axs):
    ax1 = axs[row_idx]
    experiment_name = experiments[row_idx]
    scores_df[scores_df['experiment']==experiment_name].plot(ax=ax)
    ax.axhline(13, color='black', alpha=0.5)
    ax.legend(title=experiment_name)
    ax.set_xlabel('number of episodes')
    ax.grid()

plt.savefig('report.jpg')
plt.show()

# %% [markdown]
# ### 4. Watch a Smart Agent!
#
# In the next code cell, you will load the trained weights from file to watch a smart agent!

# %%
pathname = 'models/dq_checkpoint.pth'

if torch.cuda.is_available():
    map_location=lambda storage, loc: storage.cuda()
else:
    map_location='cpu'

checkpoint = torch.load(pathname, map_location=map_location)

# %%
# load the weights from file
agent.qnetwork_local.load_state_dict(checkpoint)

for i in range(3):
    state = env.reset()
    img = plt.imshow(env.render(mode='rgb_array'))
    for j in range(200):
        action = agent.act(state)
        img.set_data(env.render(mode='rgb_array')) 
        plt.axis('off')
        display.display(plt.gcf())
        display.clear_output(wait=True)
        state, reward, done, _ = env.step(action)
        if done:
            break 
            
env.close()

# %% [markdown]
# ### 5. Explore
#
# In this exercise, you have implemented a DQN agent and demonstrated how to use it to solve an OpenAI Gym environment.  To continue your learning, you are encouraged to complete any (or all!) of the following tasks:
# - Amend the various hyperparameters and network architecture to see if you can get your agent to solve the environment faster.  Once you build intuition for the hyperparameters that work well with this environment, try solving a different OpenAI Gym task with discrete actions!
# - You may like to implement some improvements such as prioritized experience replay, Double DQN, or Dueling DQN!
# - Write a blog post explaining the intuition behind the DQN algorithm and demonstrating how to use it to solve an RL environment of your choosing.
